# %% [markdown]
# # Define the preprosession Pipeline

# %% [markdown]
# ## Import packages

# %%
from azureml.core import Workspace, Datastore, Dataset, Experiment

# %% [markdown]
# ## Conenct to the Workspace and get the compute target

# %%
#connect to the workspace
ws = Workspace.from_config(".azure")

# get the compute target
compute_target = ws.compute_targets["cpu-cluster"]

# %% [markdown]
# ## Define the Preprocessing script

# %%
# %%writefile src/preprocessing.py

from azureml.core import Workspace, Datastore, Dataset, Run
import pandas as pd
import os

# get the current run
run = Run.get_context()
ws = run.experiment.workspace

# get the dataset
ds = Dataset.get_by_name(ws, "diabetes")
diabetes_df = ds.to_pandas_dataframe()

# preprocessing here:
diabetes_df = diabetes_df[(diabetes_df["pres"] != 0) & (diabetes_df["mass"] != 0) & (diabetes_df["plas"] != 0)]

# save the data to csv
os.mkdir("data")
local_path = 'data/diabetes_cleaned.csv'
diabetes_df.to_csv(local_path, index=False)

# upload the data
datastore = ws.get_default_datastore()
datastore.upload(src_dir='data', target_path='cleaned', overwrite=True)

# create a dataset referencing the cloud location
dataset = Dataset.Tabular.from_delimited_files(path = [(datastore, ('cleaned/diabetes_cleaned.csv'))])

# register new dataset
diabetes_cleaned_ds = dataset.register(workspace=ws, name='diabetes_cleaned',description='Diabetes training data', create_new_version=True)
# Out:
# Overwriting src/preprocessing.py

# %% [markdown]
# ## Create the preprocessing Pipeline

# %%
from azureml.pipeline.core import Pipeline
from azureml.pipeline.steps import PythonScriptStep

# define the pipeline step
data_prep_step = PythonScriptStep(
    script_name="preprocessing.py",
    source_directory="src",
    compute_target=compute_target)

# create the pipeline
prep_pipeline = Pipeline(workspace=ws, steps=[data_prep_step])

# %% [markdown]
# ## Run the Pipeline

# %%
pipeline_run = Experiment(ws, 'preprocessing').submit(prep_pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step preprocessing.py [f7aaeb61][99388f1c-a5f8-48f1-a327-c9a52e7f8ec6], (This step will run and generate new outputs)
# Submitted PipelineRun 1404716e-6189-4649-bac6-82a849d037be
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/preprocessing/runs/1404716e-6189-4649-bac6-82a849d037be?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
# PipelineRunId: 1404716e-6189-4649-bac6-82a849d037be
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/preprocessing/runs/1404716e-6189-4649-bac6-82a849d037be?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: fa485a10-b3d9-498b-81e0-551d4d9ff8b0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/preprocessing/runs/fa485a10-b3d9-498b-81e0-551d4d9ff8b0?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
# StepRun( preprocessing.py ) Status: NotStarted
# StepRun( preprocessing.py ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt
# ========================================================================================================================
# 2021-02-02T00:54:58Z Starting output-watcher...
# 2021-02-02T00:54:58Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-02-02T00:54:59Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2021-02-02T00:54:59Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_b9e8a2e66019f74c902eacced9684631
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 5c77cc257b9f: Pulling fs layer
# b14701d75c08: Pulling fs layer
# 181182e3c9cf: Waiting
# 77fd611ab7bc: Pulling fs layer
# 1e2c2fdc2a5c: Pulling fs layer
# 9bb9d026b0f2: Pulling fs layer
# 0285560a98dd: Pulling fs layer
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# 5c77cc257b9f: Waiting
# b14701d75c08: Waiting
# d584ef274e55: Waiting
# 77fd611ab7bc: Waiting
# c445dda55407: Waiting
# 1e2c2fdc2a5c: Waiting
# 9bb9d026b0f2: Waiting
# 0285560a98dd: Waiting
# 33b8b485aff0: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# 5c77cc257b9f: Verifying Checksum
# 5c77cc257b9f: Download complete
# b14701d75c08: Verifying Checksum
# b14701d75c08: Download complete
# 77fd611ab7bc: Verifying Checksum
# 77fd611ab7bc: Download complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# 1e2c2fdc2a5c: Verifying Checksum
# 1e2c2fdc2a5c: Download complete
# 0285560a98dd: Verifying Checksum
# 0285560a98dd: Download complete
# 9bb9d026b0f2: Verifying Checksum
# 9bb9d026b0f2: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# 5c77cc257b9f: Pull complete
# b14701d75c08: Pull complete
# 77fd611ab7bc: Pull complete
# 1e2c2fdc2a5c: Pull complete
# 9bb9d026b0f2: Pull complete
# 0285560a98dd: Pull complete
# Digest: sha256:4442d07979d3513e2e6766c5296e947471a18a886a48631cab88a16477622db7
# Status: Downloaded newer image for amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631:latest
# amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631:latest
# 2021-02-02T00:55:54Z Check if container fa485a10-b3d9-498b-81e0-551d4d9ff8b0 already exist exited with 0,
#
# abacf3d1c10edd44a405f2f43bd936fd47ddc6bffc5a4cb8105021dd36fa5ef4
# 2021/02/02 00:56:03 Starting App Insight Logger for task:  containerSetup
# 2021/02/02 00:56:03 Version: 3.0.01474.0002 Branch: .SourceBranch Commit: 407213b
# 2021/02/02 00:56:03 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/02/02 00:56:03 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/02/02 00:56:03 sshd inside container not required for job, skipping setup.
# 2021/02/02 00:56:04 All App Insights Logs was send successfully
# 2021-02-02T00:56:04Z Starting docker container succeeded.
# 2021-02-02T00:56:08Z Job environment preparation succeeded on 10.0.0.6. Output:
# >>>   2021/02/02 00:54:55 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/02/02 00:54:55 Version: 3.0.01474.0002 Branch: .SourceBranch Commit: 407213b
# >>>   2021/02/02 00:54:55 runtime.GOOS linux
# >>>   2021/02/02 00:54:55 Reading dyanamic configs
# >>>   2021/02/02 00:54:55 Container sas url: https://baiscriptswesteuropeprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=0N9eHP7a8jepCKE6%2BOvSOLDLAmlD0xCclGbuN66nWKg%3D
# >>>   2021/02/02 00:54:55 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2021/02/02 00:54:55 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2021/02/02 00:54:55 azsecpack isEnable:false,GetDisableVsatlsscan:true
# >>>   2021/02/02 00:54:55 [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2021/02/02 00:54:55 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/02/02 00:54:55 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/02/02 00:54:55 GPU count found: 0
# >>>   2021/02/02 00:54:55 AMLComputeXDSEndpoint:  https://westeurope-prodk8ds.batchai.core.windows.net
# >>>   2021/02/02 00:54:55 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/02/02 00:54:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config
# >>>   2021/02/02 00:54:55 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/02/02 00:54:55 Starting identity responder.
# >>>   2021/02/02 00:54:55 Starting identity responder.
# >>>   2021/02/02 00:54:55 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/02/02 00:54:55 Logfile used for identity responder: /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/IdentityResponderLog-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt
# >>>   2021/02/02 00:54:55 Logfile used for identity responder: /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/IdentityResponderLog-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt
# >>>   2021/02/02 00:54:55 Started Identity Responder for job.
# >>>   2021/02/02 00:54:55 Started Identity Responder for job.
# >>>   2021/02/02 00:54:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/wd
# >>>   2021/02/02 00:54:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/shared
# >>>   2021/02/02 00:54:55 Mounting job level file systems
# >>>   2021/02/02 00:54:55 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts
# >>>   2021/02/02 00:54:55 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.amlcompute.datastorecredentials
# >>>   2021/02/02 00:54:55 Datastore credentials file not found, skipping.
# >>>   2021/02/02 00:54:55 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.master.runtimesastokens
# >>>   2021/02/02 00:54:55 Runtime sas tokens file not found, skipping.
# >>>   2021/02/02 00:54:55 No NFS configured
# >>>   2021/02/02 00:54:55 No Azure File Shares configured
# >>>   2021/02/02 00:54:55 Mounting blob file systems
# >>>   2021/02/02 00:54:55 Blobfuse runtime version 1.3.6
# >>>   2021/02/02 00:54:55 Mounting azureml-blobstore-f7e813b9-2364-48c0-8657-fb24eb686667 container from amlstorageacc account at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore
# >>>   2021/02/02 00:54:55 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/02/02 00:54:55 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/02/02 00:54:55 Blobfuse cache size set to 98149.734375 MB.
# >>>   2021/02/02 00:54:55 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=98149.734375 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/02/02 00:54:55 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore
# >>>   2021/02/02 00:54:55 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore
# >>>   2021/02/02 00:54:56 Successfully mounted azureml-blobstore-f7e813b9-2364-48c0-8657-fb24eb686667 container from amlstorageacc account at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore
# >>>   2021/02/02 00:54:56 No unmanaged file systems configured
# >>>   2021/02/02 00:54:56 From the policy service, the filtering patterns is: , data store is
# >>>   2021/02/02 00:54:56 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs
# >>>   2021/02/02 00:54:57 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/logs
# >>>   2021/02/02 00:54:58 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/outputs
# >>>   2021/02/02 00:54:58 Starting output-watcher...
# >>>   2021/02/02 00:54:58 Single file input dataset is enabled.
# >>>   2021/02/02 00:54:58 Start to pulling docker image: amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631
# >>>   2021/02/02 00:54:58 Start pull docker image: amlracr.azurecr.io
# >>>   2021/02/02 00:54:58 Container registry is ACR.
# >>>   2021/02/02 00:54:58 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/02/02 00:54:58 Getting ACR Credentials from EMS for environment Experiment preprocessing Environment:Autosave_2021-02-02T00:43:34Z_12e5fef9
# >>>   2021/02/02 00:54:58 Requesting XDS for registry details.
# >>>   2021/02/02 00:54:58 Attempt 1 of http call to https://westeurope-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourceGroups/evonik/workspaces/amlworkspace/clusters/cpu-cluster/nodes/tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d?api-version=2018-02-01
# >>>   2021/02/02 00:54:59 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2021/02/02 00:54:59 Got container registry details from credentials service for registry address: amlracr.azurecr.io.
# >>>   2021/02/02 00:54:59 Writing ACR Details to file...
# >>>   2021/02/02 00:54:59 Copying ACR Details file to worker nodes...
# >>>   2021/02/02 00:54:59 Executing 'Copy ACR Details file' on 10.0.0.6
# >>>   2021/02/02 00:54:59 Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/02/02 00:54:59 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/02/02 00:54:59 EMS returned amlracr.azurecr.io for environment Experiment preprocessing Environment
# >>>   2021/02/02 00:54:59 start login to the docker registry
# >>>   2021/02/02 00:54:59 Successfully logged into the docker registry.
# >>>   2021/02/02 00:54:59 Start run pull docker image command
# >>>   2021/02/02 00:55:53 Pull docker image succeeded.
# >>>   2021/02/02 00:55:53 Pull docker image time: 55.313470322s
# >>>
# >>>   2021/02/02 00:55:53 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/02/02 00:55:54 Setting the memory limit for docker container to be 6619 MB
# >>>   2021/02/02 00:55:54 The env variable file size is 35911 bytes
# >>>   2021/02/02 00:55:54 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,fa485a10-b3d9-498b-81e0-551d4d9ff8b0,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/certs:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,6619m,-v,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs,-v,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd,-w,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.batchai.envlist
# >>>   2021/02/02 00:55:54 the binding /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0
# >>>   2021/02/02 00:55:54 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,fa485a10-b3d9-498b-81e0-551d4d9ff8b0,-m,6619m,-w,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.batchai.envlist,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/certs:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/certs
# >>>   2021/02/02 00:55:54 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/02/02 00:55:54 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name fa485a10-b3d9-498b-81e0-551d4d9ff8b0 -m 6619m -w /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/config/.batchai.envlist -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0 -v /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd -v /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/certs:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/certs --shm-size 2g -d -it --privileged --net=host amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631
# >>>   2021/02/02 00:55:54 Check if container fa485a10-b3d9-498b-81e0-551d4d9ff8b0 already exist exited with 0,
# >>>
# >>>   2021/02/02 00:55:54 Check if container fa485a10-b3d9-498b-81e0-551d4d9ff8b0 already exist exited with 0,
# >>>
# >>>   2021/02/02 00:55:55 Attempt 1 of http call to https://westeurope.experiments.azureml.net/history/v1.0/private/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourceGroups/Evonik/providers/Microsoft.MachineLearningServices/workspaces/AMLWorkspace/runs/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/spans
# >>>   2021/02/02 00:56:04 Container ssh is not required for job type.
# >>>   2021/02/02 00:56:04 Starting docker container succeeded.
# >>>   2021/02/02 00:56:04 Starting docker container succeeded.
# >>>   2021/02/02 00:56:04 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs
# >>>   2021/02/02 00:56:04 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0-setup/job_prep.py --snapshots '[{"Id":"51536df4-42e8-46ab-afb0-51acde31f6cf","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/02 00:56:04 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs/65_job_prep-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt
# >>>   2021/02/02 00:56:04 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml_compute_logs/65_job_prep-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt
# >>>   2021/02/02 00:56:04 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0;/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0-setup/job_prep.py --snapshots '[{"Id":"51536df4-42e8-46ab-afb0-51acde31f6cf","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/02 00:56:04 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/02/02 00:56:04 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t fa485a10-b3d9-498b-81e0-551d4d9ff8b0 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/fa485a10-b3d9-498b-8_d06fee49-1e61-495c-8057-f62d218f7ca2/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0;/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0-setup/job_prep.py --snapshots '[{"Id":"51536df4-42e8-46ab-afb0-51acde31f6cf","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/02 00:56:08 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:04.595261] Entering job preparation.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:05.909120] Starting job preparation.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:05.909161] Extracting the control code.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:05.929341] fetching and extracting the control code on master node.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:05.929407] Starting extract_project.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:05.929461] Starting to extract zip file.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:06.713917] Finished extracting zip file.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:06.878248] Using urllib.request Python 3.0 or later
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:06.878310] Start fetching snapshots.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:06.878359] Start fetching snapshot.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:06.878376] Retrieving project from snapshot: 51536df4-42e8-46ab-afb0-51acde31f6cf
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 49
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.644058] Finished fetching snapshot.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.644097] Finished fetching snapshots.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.644107] Finished extract_project.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.657722] Finished fetching and extracting the control code.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.661125] downloadDataStore - Download from datastores if requested.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.663087] Start run_history_prep.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.716767] Entering context manager injector.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.767151] downloadDataStore completed
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.878333] Job preparation is complete.
# >>>   2021/02/02 00:56:08 runSpecialJobTask: preparation: [2021-02-02T00:56:07.878384] Running Context Managers in Sidecar complete.
# >>>   2021/02/02 00:56:08 All App Insights Logs was send successfully
# >>>   2021/02/02 00:56:08 Process Exiting with Code:  0
# >>>
# 2021-02-02T00:56:08Z 127.0.0.1 slots=2 max-slots=2
# 2021-02-02T00:56:08Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/02/02 00:56:08 Attempt 1 of http call to http://10.0.0.6:16384/sendlogstoartifacts/info
# 2021/02/02 00:56:09 Attempt 1 of http call to http://10.0.0.6:16384/sendlogstoartifacts/status
# [2021-02-02T00:56:10.582790] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['preprocessing.py'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 104
# Entering Run History Context Manager.
# [2021-02-02T00:56:13.231477] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0/mounts/workspaceblobstore/azureml/fa485a10-b3d9-498b-81e0-551d4d9ff8b0
# [2021-02-02T00:56:13.232285] Preparing to call script [preprocessing.py] with arguments:[]
# [2021-02-02T00:56:13.241167] After variable expansion, calling script [preprocessing.py] with arguments:[]
#
# Uploading an estimated of 1 files
#
# Streaming azureml-logs/75_job_post-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt
# ===============================================================================================================
# [2021-02-02T00:56:38.566629] Entering job release
# [2021-02-02T00:56:39.558199] Starting job release
# [2021-02-02T00:56:39.559691] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 335
# [2021-02-02T00:56:39.560122] job release stage : upload_datastore starting...
# [2021-02-02T00:56:39.569610] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-02-02T00:56:39.570186] job release stage : execute_job_release starting...
# [2021-02-02T00:56:39.571016] Entering context manager injector.
# [2021-02-02T00:56:39.571676] job release stage : copy_batchai_cached_logs starting...
# [2021-02-02T00:56:39.571799] job release stage : copy_batchai_cached_logs completed...
# [2021-02-02T00:56:39.573154] job release stage : upload_datastore completed...
# [2021-02-02T00:56:39.967298] job release stage : send_run_telemetry starting...
# [2021-02-02T00:56:39.969542] job release stage : execute_job_release completed...
# [2021-02-02T00:56:40.891707] job release stage : send_run_telemetry completed...
# [2021-02-02T00:56:40.892109] Job release is complete
#
# StepRun(preprocessing.py) Execution Summary
# ============================================
# StepRun( preprocessing.py ) Status: Finished
# {'runId': 'fa485a10-b3d9-498b-81e0-551d4d9ff8b0', 'target': 'cpu-cluster', 'status': 'Completed', 'startTimeUtc': '2021-02-02T00:54:56.128799Z', 'endTimeUtc': '2021-02-02T00:56:53.085989Z', 'properties': {'ContentSnapshotId': '51536df4-42e8-46ab-afb0-51acde31f6cf', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '99388f1c-a5f8-48f1-a327-c9a52e7f8ec6', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'f7aaeb61', 'azureml.pipelinerunid': '1404716e-6189-4649-bac6-82a849d037be', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'bd260f82-b891-4931-985b-4ff878d1c373'}, 'consumptionDetails': {'type': 'Reference'}}], 'outputDatasets': [{'identifier': {'savedId': 'c27d6152-edc4-4848-88ea-a97e23f9a312', 'registeredId': '3e0709a0-cf6c-4ccf-979e-c3d575c3dcb7', 'registeredVersion': '1'}, 'outputType': 'Reference', 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'cleaned/diabetes_cleaned.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "c27d6152-edc4-4848-88ea-a97e23f9a312",
#     "name": "diabetes_cleaned",
#     "version": 1,
#     "description": "Diabetes training data",
#     "workspace": "Workspace.create(name='AMLWorkspace', subscription_id='3a0172d3-ec0d-46bb-a88a-ff41a302711a', resource_group='Evonik')"
#   }
# }}], 'runDefinition': {'script': 'preprocessing.py', 'command': '', 'useAbsolutePath': False, 'arguments': [], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'cpu-cluster', 'dataReferences': {}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'Experiment preprocessing Environment', 'version': 'Autosave_2021-02-02T00:43:34Z_12e5fef9', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}], 'name': 'azureml_da3e97fcb51801118b8e80207f3e01ad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml-logs/55_azureml-execution-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt?sv=2019-02-02&sr=b&sig=%2FspfFaiVidUJ%2FF7EHWZdAiaA5%2BAiYm2YtKpv0TCphYc%3D&st=2021-02-02T00%3A46%3A44Z&se=2021-02-02T08%3A56%3A44Z&sp=r', 'azureml-logs/65_job_prep-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml-logs/65_job_prep-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt?sv=2019-02-02&sr=b&sig=LNchT3tG6Sj0YPwhgrexqkdILR1%2F12nRHKe18IDcm%2B8%3D&st=2021-02-02T00%3A46%3A44Z&se=2021-02-02T08%3A56%3A44Z&sp=r', 'azureml-logs/70_driver_log.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=X1Or0YNObWtCpP8PpkzO5%2B%2BfLPkHKWn%2BlpkVfjeqwkY%3D&st=2021-02-02T00%3A46%3A44Z&se=2021-02-02T08%3A56%3A44Z&sp=r', 'azureml-logs/75_job_post-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.fa485a10-b3d9-498b-81e0-551d4d9ff8b0/azureml-logs/75_job_post-tvmps_240d397ff91612a405c281b3be86f03afa65065a89c1d129738359860d5dac19_d.txt?sv=2019-02-02&sr=b&sig=a2EuhGngnyrnfsyRocwLEMEsp1cUDYTVKiCZOX28n ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '1404716e-6189-4649-bac6-82a849d037be', 'status': 'Completed', 'startTimeUtc': '2021-02-02T00:53:33.2737Z', 'endTimeUtc': '2021-02-02T00:57:07.562508Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.1404716e-6189-4649-bac6-82a849d037be/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=DBUrWbqqDFqWJgftbdZHgYAucZ3GGyYGNRkRbjLATcs%3D&st=2021-02-02T00%3A47%3A12Z&se=2021-02-02T08%3A57%3A12Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.1404716e-6189-4649-bac6-82a849d037be/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=7GaPCJJYkNNtvMEhCei6wBXk5Zu92OhBzV%2B8Zv796oc%3D&st=2021-02-02T00%3A47%3A12Z&se=2021-02-02T08%3A57%3A12Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.1404716e-6189-4649-bac6-82a849d037be/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=%2FLQrj40ptLZH0yE6L1kQtGXQKQ1hRfo9iiQvNt9I4Jg%3D&st=2021-02-02T00%3A47%3A12Z&se=2021-02-02T08%3A57%3A12Z&sp=r'}, 'submittedBy': 'Bjarne Meyn'}
# 'Finished'
