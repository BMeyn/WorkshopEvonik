# %% [markdown]
# # Putting the full Pipeline

# %% [markdown]
# ## Import the Packages

# %%
from azureml.core import Workspace, Datastore, Dataset, Experiment, Environment

# %% [markdown]
# ## Connnect to the AML Workspace

# %%
#connect to the workspace
ws = Workspace.from_config(".azure")

# get the compute target
compute_target = ws.compute_targets["cpu-cluster"]

# get the default datastore
datastore = ws.get_default_datastore()
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %% [markdown]
# ## Define the RunConfig

# %%
from azureml.core.runconfig import RunConfiguration
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.environment import CondaDependencies

from azureml.core import ScriptRunConfig

# create a new runconfig object
run_config = RunConfiguration()

# # enable Docker 
run_config.environment.docker.enabled = True

# # set Docker base image to the default CPU-based image
run_config.environment.docker.base_image = DEFAULT_CPU_IMAGE

# # # use conda_dependencies.yml to create a conda environment in the Docker image for execution
run_config.environment.python.user_managed_dependencies = True

# # specify CondaDependencies obj
run_config.environment = Environment.from_conda_specification(name = "train-env", file_path = "environment.yml")

# %% [markdown]
# ## Define the Pipeline Steps

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep
from azureml.pipeline.core.graph import PipelineParameter
from azureml.pipeline.core import Pipeline, StepSequence

# create teh ingest pipeline step
data_ingest_step = PythonScriptStep(
    script_name="data_ingest.py",
    source_directory="src",
    # outputs = [diabetes_ds],
    compute_target=compute_target)

# define the preprocessing pipeline step
data_prep_step = PythonScriptStep(
    script_name="preprocessing.py",
    source_directory="src",
    compute_target=compute_target)

# define the train pipeline step
train_DTC_step = PythonScriptStep(
    script_name="train_DTC.py",
    source_directory="src",
    compute_target="cpu-cluster",
    runconfig=run_config)

# define the pipeline step
deploy_step = PythonScriptStep(
    script_name="deploy.py",
    source_directory="src",
    compute_target=compute_target)

# run the steps in a sequence
step_sequence = StepSequence(steps=[data_ingest_step, data_prep_step, train_DTC_step, deploy_step])

# create the pipeline
pipeline = Pipeline(workspace=ws, steps=step_sequence)

# %% [markdown]
# ## Run the Pipeline

# %%
pipeline_run = Experiment(ws, 'full_pipeline').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step data_ingest.py [4a211669][51da7a5b-0320-4797-82ef-dd5a07ef40f5], (This step is eligible to reuse a previous run's output)
# Created step preprocessing.py [39ebe20d][c2416ce2-534f-49f6-953b-659f15374c43], (This step will run and generate new outputs)
# Created step train_DTC.py [6f0ff3ed][141c6cae-f40b-4c8f-b6f1-65d4f6e3943f], (This step will run and generate new outputs)
# Created step deploy.py [6103da46][30f0cc64-d6a0-4a7e-b52a-6e6f85099042], (This step will run and generate new outputs)
# Submitted PipelineRun 57d73fbf-a532-4cb0-b5bb-6fc6228b4361
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/full_pipeline/runs/57d73fbf-a532-4cb0-b5bb-6fc6228b4361?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
# PipelineRunId: 57d73fbf-a532-4cb0-b5bb-6fc6228b4361
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/full_pipeline/runs/57d73fbf-a532-4cb0-b5bb-6fc6228b4361?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 979cb0ea-6625-4c7b-bb1e-91882d9d5ec7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/full_pipeline/runs/979cb0ea-6625-4c7b-bb1e-91882d9d5ec7?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
#
# StepRun(data_ingest.py) Execution Summary
# ==========================================
# StepRun( data_ingest.py ) Status: Finished
# {'runId': '979cb0ea-6625-4c7b-bb1e-91882d9d5ec7', 'target': 'cpu-cluster', 'status': 'Completed', 'startTimeUtc': '2021-02-03T09:21:20.405178Z', 'endTimeUtc': '2021-02-03T09:21:23.481748Z', 'properties': {'azureml.reusedrunid': '478abc31-0ab6-41f5-9a23-ff8613babf41', 'azureml.reusednodeid': 'd22e1376', 'azureml.reusedpipeline': 'f29790e3-8bef-4e4d-bdb4-f276f08da38d', 'azureml.reusedpipelinerunid': 'f29790e3-8bef-4e4d-bdb4-f276f08da38d', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '4a211669', 'ContentSnapshotId': '04e88c87-bb5b-48bb-ac1c-c0254993775f', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '51da7a5b-0320-4797-82ef-dd5a07ef40f5', 'azureml.pipelinerunid': '57d73fbf-a532-4cb0-b5bb-6fc6228b4361', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'data_ingest.py', 'command': '', 'useAbsolutePath': False, 'arguments': [], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'cpu-cluster', 'dataReferences': {}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'Experiment full_pipeline Environment', 'version': 'Autosave_2021-02-03T09:10:06Z_681e2b8e', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}], 'name': 'azureml_da3e97fcb51801118b8e80207f3e01ad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_07eb647578a37d13a25dfd244828f78a6b84c829ef92bbe01cad191889a0e58d_d.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.478abc31-0ab6-41f5-9a23-ff8613babf41/azureml-logs/55_azureml-execution-tvmps_07eb647578a37d13a25dfd244828f78a6b84c829ef92bbe01cad191889a0e58d_d.txt?sv=2019-02-02&sr=b&sig=2y17ZAvfcE0HVmmWvMpQpBty1KF2eO1V8BXCBO2k0Qk%3D&st=2021-02-03T09%3A06%3A35Z&se=2021-02-03T17%3A16%3A35Z&sp=r', 'azureml-logs/65_job_prep-tvmps_07eb647578a37d13a25dfd244828f78a6b84c829ef92bbe01cad191889a0e58d_d.txt': 'https://amlstorageacc.blob.core.windows.net/azureml/ExperimentRun/dcid.478abc31-0ab6-41f5-9 ...
#
#
#
#
# StepRunId: 5db2dd59-707e-44ea-93ae-a9a31f40b93f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/full_pipeline/runs/5db2dd59-707e-44ea-93ae-a9a31f40b93f?wsid=/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourcegroups/Evonik/workspaces/AMLWorkspace
# StepRun( preprocessing.py ) Status: NotStarted
#
# Streaming azureml-logs/55_azureml-execution-tvmps_8139217f4f89e38c81aced958a80def67f4d7f21f9b2f987c170598c3830b483_d.txt
# ========================================================================================================================
# 2021-02-03T09:21:42Z Starting output-watcher...
# 2021-02-03T09:21:42Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# StepRun( preprocessing.py ) Status: Running
# 2021-02-03T09:21:43Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2021-02-03T09:21:43Z Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_b9e8a2e66019f74c902eacced9684631
# Digest: sha256:4442d07979d3513e2e6766c5296e947471a18a886a48631cab88a16477622db7
# Status: Image is up to date for amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631:latest
# amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631:latest
# 2021-02-03T09:21:44Z Check if container 5db2dd59-707e-44ea-93ae-a9a31f40b93f already exist exited with 0,
#
# b1fc8d788fbef919ab13406b2dc40d478a2662d91d0bb803174eef7c436c33ab
# 2021/02/03 09:21:45 Starting App Insight Logger for task:  containerSetup
# 2021/02/03 09:21:45 Version: 3.0.01485.0006 Branch: 2 Commit: a809e28
# 2021/02/03 09:21:45 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/02/03 09:21:45 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/02/03 09:21:45 sshd inside container not required for job, skipping setup.
# 2021/02/03 09:21:46 All App Insights Logs was send successfully
# 2021-02-03T09:21:46Z Starting docker container succeeded.
# 2021-02-03T09:21:52Z Job environment preparation succeeded on 10.0.0.7. Output:
# >>>   2021/02/03 09:21:39 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/02/03 09:21:39 Version: 3.0.01485.0006 Branch: 2 Commit: a809e28
# >>>   2021/02/03 09:21:39 runtime.GOOS linux
# >>>   2021/02/03 09:21:39 Reading dyanamic configs
# >>>   2021/02/03 09:21:39 Container sas url: https://baiscriptswesteuropeprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=9UBH7ig8b9NIeIkNQpNxDmP7wUMtSqFoIE5AY22cheE%3D
# >>>   2021/02/03 09:21:39 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2021/02/03 09:21:39 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2021/02/03 09:21:39 azsecpack isEnable:false,GetDisableVsatlsscan:true
# >>>   2021/02/03 09:21:39 [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2021/02/03 09:21:39 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/02/03 09:21:39 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/02/03 09:21:39 Start to getting gpu count by running nvidia-smi command
# >>>   2021/02/03 09:21:39 Get GPU count failed with err: exit status 9, NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
# >>>
# >>>
# >>>   2021/02/03 09:21:39 AMLComputeXDSEndpoint:  https://westeurope-prodk8ds.batchai.core.windows.net
# >>>   2021/02/03 09:21:39 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/02/03 09:21:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config
# >>>   2021/02/03 09:21:39 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/02/03 09:21:39 Starting identity responder.
# >>>   2021/02/03 09:21:39 Starting identity responder.
# >>>   2021/02/03 09:21:39 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/02/03 09:21:39 Logfile used for identity responder: /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/IdentityResponderLog-tvmps_8139217f4f89e38c81aced958a80def67f4d7f21f9b2f987c170598c3830b483_d.txt
# >>>   2021/02/03 09:21:39 Logfile used for identity responder: /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/IdentityResponderLog-tvmps_8139217f4f89e38c81aced958a80def67f4d7f21f9b2f987c170598c3830b483_d.txt
# >>>   2021/02/03 09:21:39 Started Identity Responder for job.
# >>>   2021/02/03 09:21:39 Started Identity Responder for job.
# >>>   2021/02/03 09:21:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/wd
# >>>   2021/02/03 09:21:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/shared
# >>>   2021/02/03 09:21:39 Mounting job level file systems
# >>>   2021/02/03 09:21:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts
# >>>   2021/02/03 09:21:39 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.amlcompute.datastorecredentials
# >>>   2021/02/03 09:21:39 Datastore credentials file not found, skipping.
# >>>   2021/02/03 09:21:39 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.master.runtimesastokens
# >>>   2021/02/03 09:21:39 Runtime sas tokens file not found, skipping.
# >>>   2021/02/03 09:21:39 No NFS configured
# >>>   2021/02/03 09:21:39 No Azure File Shares configured
# >>>   2021/02/03 09:21:39 Mounting blob file systems
# >>>   2021/02/03 09:21:39 Blobfuse runtime version 1.3.6
# >>>   2021/02/03 09:21:39 Mounting azureml-blobstore-f7e813b9-2364-48c0-8657-fb24eb686667 container from amlstorageacc account at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore
# >>>   2021/02/03 09:21:39 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/02/03 09:21:39 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/02/03 09:21:39 Blobfuse cache size set to 90262 MB.
# >>>   2021/02/03 09:21:39 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=90262 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/02/03 09:21:39 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore
# >>>   2021/02/03 09:21:39 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore
# >>>   2021/02/03 09:21:39 Successfully mounted azureml-blobstore-f7e813b9-2364-48c0-8657-fb24eb686667 container from amlstorageacc account at /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore
# >>>   2021/02/03 09:21:39 No unmanaged file systems configured
# >>>   2021/02/03 09:21:39 Start to getting gpu count by running nvidia-smi command
# >>>   2021/02/03 09:21:39 From the policy service, the filtering patterns is: , data store is
# >>>   2021/02/03 09:21:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs
# >>>   2021/02/03 09:21:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/logs
# >>>   2021/02/03 09:21:41 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/outputs
# >>>   2021/02/03 09:21:42 Starting output-watcher...
# >>>   2021/02/03 09:21:42 Single file input dataset is enabled.
# >>>   2021/02/03 09:21:42 Start to pulling docker image: amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631
# >>>   2021/02/03 09:21:42 Start pull docker image: amlracr.azurecr.io
# >>>   2021/02/03 09:21:42 Container registry is ACR.
# >>>   2021/02/03 09:21:42 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/02/03 09:21:42 Getting ACR Credentials from EMS for environment Experiment full_pipeline Environment:Autosave_2021-02-03T09:10:06Z_681e2b8e
# >>>   2021/02/03 09:21:42 Requesting XDS for registry details.
# >>>   2021/02/03 09:21:42 Attempt 1 of http call to https://westeurope-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourceGroups/evonik/workspaces/amlworkspace/clusters/cpu-cluster/nodes/tvmps_8139217f4f89e38c81aced958a80def67f4d7f21f9b2f987c170598c3830b483_d?api-version=2018-02-01
# >>>   2021/02/03 09:21:43 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2021/02/03 09:21:43 Got container registry details from credentials service for registry address: amlracr.azurecr.io.
# >>>   2021/02/03 09:21:43 Writing ACR Details to file...
# >>>   2021/02/03 09:21:43 Copying ACR Details file to worker nodes...
# >>>   2021/02/03 09:21:43 Executing 'Copy ACR Details file' on 10.0.0.7
# >>>   2021/02/03 09:21:43 Begin executing task on Node
# >>>   2021/02/03 09:21:43 Task on Node result: succeeded
# >>>   2021/02/03 09:21:43 Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/02/03 09:21:43 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/02/03 09:21:43 EMS returned amlracr.azurecr.io for environment Experiment full_pipeline Environment
# >>>   2021/02/03 09:21:43 start login to the docker registry
# >>>   2021/02/03 09:21:43 Successfully logged into the docker registry.
# >>>   2021/02/03 09:21:43 Start run pull docker image command
# >>>   2021/02/03 09:21:44 Pull docker image succeeded.
# >>>   2021/02/03 09:21:44 Pull docker image time: 1.649267006s
# >>>
# >>>   2021/02/03 09:21:44 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/02/03 09:21:44 Start to getting gpu count by running nvidia-smi command
# >>>   2021/02/03 09:21:44 Setting the memory limit for docker container to be 6619 MB
# >>>   2021/02/03 09:21:44 The env variable file size is 36115 bytes
# >>>   2021/02/03 09:21:44 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,5db2dd59-707e-44ea-93ae-a9a31f40b93f,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/certs:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,6619m,-v,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs,-v,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd,-w,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.batchai.envlist
# >>>   2021/02/03 09:21:44 the binding /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f
# >>>   2021/02/03 09:21:44 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,5db2dd59-707e-44ea-93ae-a9a31f40b93f,-m,6619m,-w,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.batchai.envlist,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd,-v,/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/certs:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/certs
# >>>   2021/02/03 09:21:44 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/02/03 09:21:44 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 5db2dd59-707e-44ea-93ae-a9a31f40b93f -m 6619m -w /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/config/.batchai.envlist -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f:/mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f -v /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd -v /mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/certs:/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/certs --shm-size 2g -d -it --privileged --net=host amlracr.azurecr.io/azureml/azureml_b9e8a2e66019f74c902eacced9684631
# >>>   2021/02/03 09:21:44 Check if container 5db2dd59-707e-44ea-93ae-a9a31f40b93f already exist exited with 0,
# >>>
# >>>   2021/02/03 09:21:44 Check if container 5db2dd59-707e-44ea-93ae-a9a31f40b93f already exist exited with 0,
# >>>
# >>>   2021/02/03 09:21:44 Attempt 1 of http call to https://westeurope.experiments.azureml.net/history/v1.0/private/subscriptions/3a0172d3-ec0d-46bb-a88a-ff41a302711a/resourceGroups/Evonik/providers/Microsoft.MachineLearningServices/workspaces/AMLWorkspace/runs/5db2dd59-707e-44ea-93ae-a9a31f40b93f/spans
# >>>   2021/02/03 09:21:46 Container ssh is not required for job type.
# >>>   2021/02/03 09:21:46 Starting docker container succeeded.
# >>>   2021/02/03 09:21:46 Starting docker container succeeded.
# >>>   2021/02/03 09:21:46 Disk space after starting docker container: 92776MB
# >>>   2021/02/03 09:21:46 Begin execution of runSpecialJobTask
# >>>   2021/02/03 09:21:46 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs
# >>>   2021/02/03 09:21:46 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f-setup/job_prep.py --snapshots '[{"Id":"04e88c87-bb5b-48bb-ac1c-c0254993775f","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/03 09:21:46 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs/65_job_prep-tvmps_8139217f4f89e38c81aced958a80def67f4d7f21f9b2f987c170598c3830b483_d.txt
# >>>   2021/02/03 09:21:46 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/azureml_compute_logs/65_job_prep-tvmps_8139217f4f89e38c81aced958a80def67f4d7f21f9b2f987c170598c3830b483_d.txt
# >>>   2021/02/03 09:21:46 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f;/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f-setup/job_prep.py --snapshots '[{"Id":"04e88c87-bb5b-48bb-ac1c-c0254993775f","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/03 09:21:46 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/02/03 09:21:47 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t 5db2dd59-707e-44ea-93ae-a9a31f40b93f bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/ca1df6de-6a37-469d-aa81-df951f5b0f10/job-1/5db2dd59-707e-44ea-9_44661dbf-84dc-4e2e-8020-0e42e4ad2248/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f;/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f-setup/job_prep.py --snapshots '[{"Id":"04e88c87-bb5b-48bb-ac1c-c0254993775f","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/03 09:21:51 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:47.755010] Entering job preparation.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:49.052279] Starting job preparation.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:49.052318] Extracting the control code.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:49.114911] fetching and extracting the control code on master node.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:49.114960] Starting extract_project.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:49.115013] Starting to extract zip file.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:49.892067] Finished extracting zip file.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:50.050426] Using urllib.request Python 3.0 or later
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:50.050490] Start fetching snapshots.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:50.050532] Start fetching snapshot.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:50.050563] Retrieving project from snapshot: 04e88c87-bb5b-48bb-ac1c-c0254993775f
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 49
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.308371] Finished fetching snapshot.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.308406] Finished fetching snapshots.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.308491] Finished extract_project.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.320663] Finished fetching and extracting the control code.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.323694] downloadDataStore - Download from datastores if requested.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.325492] Start run_history_prep.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.383680] Entering context manager injector.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.434114] downloadDataStore completed
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.572415] Job preparation is complete.
# >>>   2021/02/03 09:21:51 runSpecialJobTask: preparation: [2021-02-03T09:21:51.572464] Running Context Managers in Sidecar complete.
# >>>   2021/02/03 09:21:51 Execution of runSpecialJobTask completed
# >>>   2021/02/03 09:21:52 All App Insights Logs was send successfully
# >>>   2021/02/03 09:21:52 Process Exiting with Code:  0
# >>>
# 2021-02-03T09:21:52Z 127.0.0.1 slots=2 max-slots=2
# 2021-02-03T09:21:52Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/02/03 09:21:52 Attempt 1 of http call to http://10.0.0.7:16384/sendlogstoartifacts/info
# 2021/02/03 09:21:52 Attempt 1 of http call to http://10.0.0.7:16384/sendlogstoartifacts/status
# [2021-02-03T09:21:54.109953] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['preprocessing.py'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 105
# Entering Run History Context Manager.
# [2021-02-03T09:21:56.991126] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/amlworkspace/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f/mounts/workspaceblobstore/azureml/5db2dd59-707e-44ea-93ae-a9a31f40b93f
# [2021-02-03T09:21:56.991340] Preparing to call script [preprocessing.py] with arguments:[]
# [2021-02-03T09:21:56.991760] After variable expansion, calling script [preprocessing.py] with arguments:[]
